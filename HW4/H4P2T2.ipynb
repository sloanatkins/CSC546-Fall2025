# %% [markdown]
# ### H4P2T2: Build a CNN with residual connections for ECG Signal Classification (5 classes)

# %% [markdown]
# ### Read H4P2_torchview.ipynb first

# %%
#Create your "signature"
#Run this cell but do NOT modify the code.
#The signature needs to be displayed right below the cell in this file.
#You will get zero point if the signature is not displayed.     
import platform, socket, getpass
from time import time
from datetime import datetime
import random
signature=[socket.gethostbyname(socket.gethostname()),
           getpass.getuser(),
           datetime.now(),
           random.random()]
print(signature)
# Out:
# ['127.0.0.1', 'sloanatkins', datetime.datetime(2025, 11, 24, 12, 14, 28, 602325), 0.6882866425963848]

# %%
#do not modify this cell
import os
import numpy as np
np.random.seed(seed=None)
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim
import platform, socket, getpass
from time import time
from datetime import datetime

# %% [markdown]
# ### Design a CNN -  modify the cell below

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        #---------------------------------------------------------Instructions-----------------------------------------------------------
        # replace each * with a suitable layer according to the diagram in Homework4.pdf
        #   for example: change self.conv1 = * to self.conv1=nn.Conv1d(in_channels=?, out_channels=?, kernel_size=?, stride=?, padding=?)
        # replace each ? with a suitable value
        #   for example: change in_channels=? to in_channels=1 in self.conv1
        # do NOT replace/change anything eslse
        # do NOT add new layers    
        #---------------------------------------------------------------------------------------------------------------------------------
        self.conv1 = nn.Conv1d(1, 32, 3, 1, 1)
        self.conv2 = nn.Conv1d(32, 32, 3, 1, 1)

        self.norm3 = nn.GroupNorm(1, 32)
        self.conv3 = nn.Conv1d(32, 32, 3, 1, 1)

        self.norm4 = nn.GroupNorm(1, 32)
        self.conv4 = nn.Conv1d(32, 32, 3, 1, 1)

        self.norm5 = nn.GroupNorm(1, 32)
        self.conv5 = nn.Conv1d(32, 32, 3, 1, 1)

        self.avg1 = nn.AvgPool1d(2, 2, 0)
        self.avg2 = nn.AvgPool1d(2, 2, 0)
        self.avg3 = nn.AvgPool1d(2, 2, 0)

        self.fc1 = nn.Linear(32 * 46, 128)
        self.fc2 = nn.Linear(128, 5)

    def forward(self, x):
        #-----------------Instructions---------------------------------
        #connect the layers according to the diagram in Homework4.pdf
        #ReLU in the diagram refers to nnF.relu, which is used here
        #use variable names according to the diagram in Homework4.pdf
        #     for example: x1=nnF.relu(self.conv1(x)) 
        #to debug you code: print the shape of the output from every layer
        #    for example: print("x1", x1.shape)
        #--------------------------------------------------------------
        x1 = nnF.relu(self.conv1(x))
        x2 = nnF.relu(self.conv2(x1)) 
        x1a = self.avg1(x1) 

        x2p = self.avg2(x2) 
        x3b = nnF.relu(self.conv3(self.norm3(x2p)))
        x3 = x3b + x1a  

        x3p = self.avg3(x3) 
        x4b = nnF.relu(self.conv4(self.norm4(x3p)))
        x4 = x4b + x3p  

        x5 = nnF.relu(self.conv5(self.norm5(x4)))  

        x5r = x5.reshape(x5.size(0), -1) 
        x6 = nnF.relu(self.fc1(x5r))
        z = self.fc2(x6)
        return z

# %%
#debug your network here
model=Net()
x=torch.rand(10,1,187)
z=model(x)
print(z.shape) # (10, 5)
# Out:
# torch.Size([10, 5])

# %% [markdown]
# ### Read and Run, but do NOT modify any code below this line
# ### You may get zero score if you modify any code below this line

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        optimizer.zero_grad()#clear grad of each parameter
        loss.backward()#backward pass
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1, norm_type=2)
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5), dtype=np.int64)
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result,
                'other':[platform.node(), 
                         socket.gethostbyname(socket.gethostname()), 
                         getpass.getuser(),
                         datetime.now(),
                         np.random.rand()]},
               filename)
    print('saved:', filename)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        x=x.reshape(1,-1)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
#use a smaller batch_size if necessary
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
x=dataset_train[0][0]
x=x.view(1,1,187).to(device)
z=model(x)

# %%
y_hat=nnF.softmax(z, dim=1)
y_hat
# Out:
# tensor([[0.2036, 0.2043, 0.2042, 0.1855, 0.2024]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# choose an optimization method

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001, amsgrad=True)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
val_acc_best=0

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(0, 100):
    t0=time()
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    if acc_val > val_acc_best:
        val_acc_best=acc_val
        result = (loss_train_list, acc_train_list, 
                  acc_val_list, other_val)
        save_checkpoint('H4P2T2_CNN_best.pt', model, optimizer, result, epoch)    
    t1=time()
    print('epoch', epoch, 'time cost:', t1-t0)
# Out:
# Train Epoch: 0 [0%]	Loss: 1.606491
# epoch 0 training loss: 1.1358792348341509 acc: 0.5492040520984081
# epoch 0 validation acc: 0.6915584
# saved: H4P2T2_CNN_best.pt
# epoch 0 time cost: 1.524176836013794
# Train Epoch: 1 [0%]	Loss: 0.717949
# epoch 1 training loss: 0.7366281043399464 acc: 0.7463820549927641
# epoch 1 validation acc: 0.7467533
# saved: H4P2T2_CNN_best.pt
# epoch 1 time cost: 1.3867812156677246
# Train Epoch: 2 [0%]	Loss: 0.562319
# epoch 2 training loss: 0.6110365119847384 acc: 0.774602026049204
# epoch 2 validation acc: 0.77597404
# saved: H4P2T2_CNN_best.pt
# epoch 2 time cost: 1.3455150127410889
# Train Epoch: 3 [0%]	Loss: 0.432563
# epoch 3 training loss: 0.520492897792296 acc: 0.8122286541244573
# epoch 3 validation acc: 0.7922078
# saved: H4P2T2_CNN_best.pt
# epoch 3 time cost: 1.3159968852996826
# Train Epoch: 4 [0%]	Loss: 0.345109
# epoch 4 training loss: 0.4614507420496507 acc: 0.8328509406657019
# epoch 4 validation acc: 0.8019481
# saved: H4P2T2_CNN_best.pt
# epoch 4 time cost: 1.3163588047027588
# Train Epoch: 5 [0%]	Loss: 0.412536
# epoch 5 training loss: 0.41190058941190894 acc: 0.8534732272069464
# epoch 5 validation acc: 0.84090906
# saved: H4P2T2_CNN_best.pt
# epoch 5 time cost: 1.3450989723205566
# Train Epoch: 6 [0%]	Loss: 0.340616
# epoch 6 training loss: 0.3703952966765924 acc: 0.8654124457308249
# epoch 6 validation acc: 0.8214286
# epoch 6 time cost: 1.3140478134155273
# Train Epoch: 7 [0%]	Loss: 0.271616
# epoch 7 training loss: 0.3260458389466459 acc: 0.8842257597684515
# epoch 7 validation acc: 0.8603896
# saved: H4P2T2_CNN_best.pt
# epoch 7 time cost: 1.80892014503479
# Train Epoch: 8 [0%]	Loss: 0.281872
# epoch 8 training loss: 0.2923827977343039 acc: 0.8958031837916064
# epoch 8 validation acc: 0.8636364
# saved: H4P2T2_CNN_best.pt
# epoch 8 time cost: 1.6332447528839111
# Train Epoch: 9 [0%]	Loss: 0.361761
# epoch 9 training loss: 0.2627475993199782 acc: 0.900506512301013
# epoch 9 validation acc: 0.8603896
# epoch 9 time cost: 1.4919607639312744
# Train Epoch: 10 [0%]	Loss: 0.207949
# epoch 10 training loss: 0.23973310738801956 acc: 0.91027496382055
# epoch 10 validation acc: 0.84090906
# epoch 10 time cost: 1.39935302734375
# Train Epoch: 11 [0%]	Loss: 0.269047
# epoch 11 training loss: 0.20632407814264297 acc: 0.9283646888567294
# epoch 11 validation acc: 0.8701299
# saved: H4P2T2_CNN_best.pt
# epoch 11 time cost: 1.3795650005340576
# Train Epoch: 12 [0%]	Loss: 0.230345
# epoch 12 training loss: 0.19055395302447406 acc: 0.9337916063675832
# epoch 12 validation acc: 0.8668831
# epoch 12 time cost: 1.3162009716033936
# Train Epoch: 13 [0%]	Loss: 0.180710
# epoch 13 training loss: 0.16953191499818454 acc: 0.9421128798842258
# epoch 13 validation acc: 0.8538961
# epoch 13 time cost: 1.3158299922943115
# Train Epoch: 14 [0%]	Loss: 0.157098
# epoch 14 training loss: 0.15840656919912857 acc: 0.947178002894356
# epoch 14 validation acc: 0.8668831
# epoch 14 time cost: 1.3133490085601807
# Train Epoch: 15 [0%]	Loss: 0.127185
# epoch 15 training loss: 0.1508160721171986 acc: 0.9475397973950795
# epoch 15 validation acc: 0.8766234
# saved: H4P2T2_CNN_best.pt
# epoch 15 time cost: 1.3256299495697021
# Train Epoch: 16 [0%]	Loss: 0.155891
# epoch 16 training loss: 0.13706549968231807 acc: 0.9576700434153401
# epoch 16 validation acc: 0.8538961
# epoch 16 time cost: 1.3523809909820557
# Train Epoch: 17 [0%]	Loss: 0.105059
# epoch 17 training loss: 0.11901190267367796 acc: 0.9623733719247467
# epoch 17 validation acc: 0.8636364
# epoch 17 time cost: 1.3701131343841553
# Train Epoch: 18 [0%]	Loss: 0.101199
# epoch 18 training loss: 0.10468773154372518 acc: 0.9634587554269175
# epoch 18 validation acc: 0.8733766
# epoch 18 time cost: 1.3515191078186035
# Train Epoch: 19 [0%]	Loss: 0.101219
# epoch 19 training loss: 0.09420619634064761 acc: 0.967438494934877
# epoch 19 validation acc: 0.8798701
# saved: H4P2T2_CNN_best.pt
# epoch 19 time cost: 1.3488619327545166
# Train Epoch: 20 [0%]	Loss: 0.081333
# epoch 20 training loss: 0.09211810678243637 acc: 0.9710564399421129
# epoch 20 validation acc: 0.8668831
# epoch 20 time cost: 1.3174951076507568
# Train Epoch: 21 [0%]	Loss: 0.053687
# epoch 21 training loss: 0.0826509938659993 acc: 0.9732272069464544
# epoch 21 validation acc: 0.8733766
# epoch 21 time cost: 1.3306770324707031
# Train Epoch: 22 [0%]	Loss: 0.077987
# epoch 22 training loss: 0.06747765991498124 acc: 0.9779305354558611
# epoch 22 validation acc: 0.8701299
# epoch 22 time cost: 1.3510758876800537
# Train Epoch: 23 [0%]	Loss: 0.089966
# epoch 23 training loss: 0.05850355665792118 acc: 0.9808248914616498
# epoch 23 validation acc: 0.8603896
# epoch 23 time cost: 1.3113901615142822
# Train Epoch: 24 [0%]	Loss: 0.040937
# epoch 24 training loss: 0.04890118065205487 acc: 0.9873371924746743
# epoch 24 validation acc: 0.8701299
# epoch 24 time cost: 1.3406920433044434
# Train Epoch: 25 [0%]	Loss: 0.017312
# epoch 25 training loss: 0.0522483766332946 acc: 0.9876989869753979
# epoch 25 validation acc: 0.8766234
# epoch 25 time cost: 1.3121659755706787
# Train Epoch: 26 [0%]	Loss: 0.019927
# epoch 26 training loss: 0.04214237063107165 acc: 0.9884225759768451
# epoch 26 validation acc: 0.8798701
# epoch 26 time cost: 1.3382620811462402
# Train Epoch: 27 [0%]	Loss: 0.013029
# epoch 27 training loss: 0.048063872678374704 acc: 0.983357452966715
# epoch 27 validation acc: 0.8668831
# epoch 27 time cost: 1.3175270557403564
# Train Epoch: 28 [0%]	Loss: 0.014347
# epoch 28 training loss: 0.037195496007122776 acc: 0.9869753979739508
# epoch 28 validation acc: 0.8701299
# epoch 28 time cost: 1.3128142356872559
# Train Epoch: 29 [0%]	Loss: 0.016538
# epoch 29 training loss: 0.04067184742201458 acc: 0.9880607814761215
# epoch 29 validation acc: 0.8766234
# epoch 29 time cost: 1.3378181457519531
# Train Epoch: 30 [0%]	Loss: 0.031565
# epoch 30 training loss: 0.03627393128011714 acc: 0.9895079594790159
# epoch 30 validation acc: 0.8636364
# epoch 30 time cost: 1.3230578899383545
# Train Epoch: 31 [0%]	Loss: 0.050035
# epoch 31 training loss: 0.036182790232652966 acc: 0.9891461649782923
# epoch 31 validation acc: 0.8668831
# epoch 31 time cost: 1.4045002460479736
# Train Epoch: 32 [0%]	Loss: 0.056229
# epoch 32 training loss: 0.0510427210141312 acc: 0.9790159189580319
# epoch 32 validation acc: 0.8863636
# saved: H4P2T2_CNN_best.pt
# epoch 32 time cost: 1.3199009895324707
# Train Epoch: 33 [0%]	Loss: 0.015986
# epoch 33 training loss: 0.03324652236716991 acc: 0.992040520984081
# epoch 33 validation acc: 0.89935064
# saved: H4P2T2_CNN_best.pt
# epoch 33 time cost: 1.3469188213348389
# Train Epoch: 34 [0%]	Loss: 0.012734
# epoch 34 training loss: 0.028183198957280678 acc: 0.9898697539797395
# epoch 34 validation acc: 0.8831169
# epoch 34 time cost: 1.3248629570007324
# Train Epoch: 35 [0%]	Loss: 0.008811
# epoch 35 training loss: 0.022400020388886333 acc: 0.9934876989869754
# epoch 35 validation acc: 0.8831169
# epoch 35 time cost: 1.3160738945007324
# Train Epoch: 36 [0%]	Loss: 0.010617
# epoch 36 training loss: 0.029250811467963187 acc: 0.9902315484804631
# epoch 36 validation acc: 0.8668831
# epoch 36 time cost: 1.3113677501678467
# Train Epoch: 37 [0%]	Loss: 0.018646
# epoch 37 training loss: 0.03249725607350807 acc: 0.9891461649782923
# epoch 37 validation acc: 0.8603896
# epoch 37 time cost: 1.3215911388397217
# Train Epoch: 38 [0%]	Loss: 0.028097
# epoch 38 training loss: 0.03545326263305138 acc: 0.9898697539797395
# epoch 38 validation acc: 0.8668831
# epoch 38 time cost: 1.336812973022461
# Train Epoch: 39 [0%]	Loss: 0.006315
# epoch 39 training loss: 0.02258945455436002 acc: 0.9927641099855282
# epoch 39 validation acc: 0.85064936
# epoch 39 time cost: 1.3161242008209229
# Train Epoch: 40 [0%]	Loss: 0.054977
# epoch 40 training loss: 0.02194392451466146 acc: 0.9924023154848046
# epoch 40 validation acc: 0.8733766
# epoch 40 time cost: 1.3421897888183594
# Train Epoch: 41 [0%]	Loss: 0.015692
# epoch 41 training loss: 0.016308804000304503 acc: 0.9956584659913169
# epoch 41 validation acc: 0.8863636
# epoch 41 time cost: 1.3141131401062012
# Train Epoch: 42 [0%]	Loss: 0.016528
# epoch 42 training loss: 0.016812200980811296 acc: 0.9945730824891461
# epoch 42 validation acc: 0.8733766
# epoch 42 time cost: 1.3123180866241455
# Train Epoch: 43 [0%]	Loss: 0.008643
# epoch 43 training loss: 0.020385207724757493 acc: 0.9931259044862518
# epoch 43 validation acc: 0.8733766
# epoch 43 time cost: 1.314100980758667
# Train Epoch: 44 [0%]	Loss: 0.006852
# epoch 44 training loss: 0.011368255877063017 acc: 0.9967438494934877
# epoch 44 validation acc: 0.8831169
# epoch 44 time cost: 1.3400650024414062
# Train Epoch: 45 [0%]	Loss: 0.023979
# epoch 45 training loss: 0.010899368980476125 acc: 0.9967438494934877
# epoch 45 validation acc: 0.8798701
# epoch 45 time cost: 1.3186290264129639
# Train Epoch: 46 [0%]	Loss: 0.005908
# epoch 46 training loss: 0.007832014541649683 acc: 0.9978292329956585
# epoch 46 validation acc: 0.8733766
# epoch 46 time cost: 1.3381550312042236
# Train Epoch: 47 [0%]	Loss: 0.005691
# epoch 47 training loss: 0.006136920266065069 acc: 0.9985528219971056
# epoch 47 validation acc: 0.8636364
# epoch 47 time cost: 1.3617589473724365
# Train Epoch: 48 [0%]	Loss: 0.027326
# epoch 48 training loss: 0.015515311166051437 acc: 0.9945730824891461
# epoch 48 validation acc: 0.8798701
# epoch 48 time cost: 1.4135520458221436
# Train Epoch: 49 [0%]	Loss: 0.021136
# epoch 49 training loss: 0.01135379633739252 acc: 0.9963820549927641
# epoch 49 validation acc: 0.8798701
# epoch 49 time cost: 1.4075348377227783
# Train Epoch: 50 [0%]	Loss: 0.000726
# epoch 50 training loss: 0.012881089578679 acc: 0.9971056439942113
# epoch 50 validation acc: 0.8831169
# epoch 50 time cost: 1.3134660720825195
# Train Epoch: 51 [0%]	Loss: 0.004015
# epoch 51 training loss: 0.006327116359236904 acc: 0.9974674384949349
# epoch 51 validation acc: 0.8701299
# epoch 51 time cost: 1.3403029441833496
# Train Epoch: 52 [0%]	Loss: 0.004121
# epoch 52 training loss: 0.012956609547307546 acc: 0.9956584659913169
# epoch 52 validation acc: 0.8668831
# epoch 52 time cost: 1.334702730178833
# Train Epoch: 53 [0%]	Loss: 0.001730
# epoch 53 training loss: 0.019743189162744038 acc: 0.9934876989869754
# epoch 53 validation acc: 0.8701299
# epoch 53 time cost: 1.315073013305664
# Train Epoch: 54 [0%]	Loss: 0.053753
# epoch 54 training loss: 0.012786905842155895 acc: 0.9967438494934877
# epoch 54 validation acc: 0.8668831
# epoch 54 time cost: 1.3189661502838135
# Train Epoch: 55 [0%]	Loss: 0.010636
# epoch 55 training loss: 0.013092734163034369 acc: 0.9963820549927641
# epoch 55 validation acc: 0.8733766
# epoch 55 time cost: 1.3999342918395996
# Train Epoch: 56 [0%]	Loss: 0.001143
# epoch 56 training loss: 0.008236402489604767 acc: 0.9967438494934877
# epoch 56 validation acc: 0.8863636
# epoch 56 time cost: 1.3167428970336914
# Train Epoch: 57 [0%]	Loss: 0.005637
# epoch 57 training loss: 0.012920567173172127 acc: 0.9971056439942113
# epoch 57 validation acc: 0.8733766
# epoch 57 time cost: 1.3148090839385986
# Train Epoch: 58 [0%]	Loss: 0.010279
# epoch 58 training loss: 0.006056557020532306 acc: 0.9978292329956585
# epoch 58 validation acc: 0.8896104
# epoch 58 time cost: 1.3175311088562012
# Train Epoch: 59 [0%]	Loss: 0.000912
# epoch 59 training loss: 0.007823311997609298 acc: 0.9971056439942113
# epoch 59 validation acc: 0.8798701
# epoch 59 time cost: 1.3177490234375
# Train Epoch: 60 [0%]	Loss: 0.012168
# epoch 60 training loss: 0.01458761619340459 acc: 0.9960202604920405
# epoch 60 validation acc: 0.8766234
# epoch 60 time cost: 1.3397750854492188
# Train Epoch: 61 [0%]	Loss: 0.013720
# epoch 61 training loss: 0.007704983015587045 acc: 0.9974674384949349
# epoch 61 validation acc: 0.8668831
# epoch 61 time cost: 1.427751064300537
# Train Epoch: 62 [0%]	Loss: 0.000920
# epoch 62 training loss: 0.0058852977844336156 acc: 0.998191027496382
# epoch 62 validation acc: 0.8701299
# epoch 62 time cost: 1.3476228713989258
# Train Epoch: 63 [0%]	Loss: 0.007586
# epoch 63 training loss: 0.002477879557938484 acc: 0.9996382054992764
# epoch 63 validation acc: 0.8766234
# epoch 63 time cost: 1.3150720596313477
# Train Epoch: 64 [0%]	Loss: 0.003282
# epoch 64 training loss: 0.0013417157513851469 acc: 1.0
# epoch 64 validation acc: 0.8863636
# epoch 64 time cost: 1.3219890594482422
# Train Epoch: 65 [0%]	Loss: 0.001408
# epoch 65 training loss: 0.001418301637882409 acc: 1.0
# epoch 65 validation acc: 0.8863636
# epoch 65 time cost: 1.3386681079864502
# Train Epoch: 66 [0%]	Loss: 0.010128
# epoch 66 training loss: 0.0033139476231140593 acc: 0.9985528219971056
# epoch 66 validation acc: 0.8896104
# epoch 66 time cost: 1.3109498023986816
# Train Epoch: 67 [0%]	Loss: 0.000681
# epoch 67 training loss: 0.00775982060242148 acc: 0.9974674384949349
# epoch 67 validation acc: 0.8668831
# epoch 67 time cost: 1.3852591514587402
# Train Epoch: 68 [0%]	Loss: 0.000612
# epoch 68 training loss: 0.004872068343419497 acc: 0.9989146164978292
# epoch 68 validation acc: 0.8863636
# epoch 68 time cost: 1.3145532608032227
# Train Epoch: 69 [0%]	Loss: 0.007731
# epoch 69 training loss: 0.001253122533936138 acc: 1.0
# epoch 69 validation acc: 0.8863636
# epoch 69 time cost: 1.3410711288452148
# Train Epoch: 70 [0%]	Loss: 0.000567
# epoch 70 training loss: 0.0006054220311026173 acc: 1.0
# epoch 70 validation acc: 0.8798701
# epoch 70 time cost: 1.3146491050720215
# Train Epoch: 71 [0%]	Loss: 0.000400
# epoch 71 training loss: 0.0006519655005170287 acc: 1.0
# epoch 71 validation acc: 0.8798701
# epoch 71 time cost: 1.3159911632537842
# Train Epoch: 72 [0%]	Loss: 0.000233
# epoch 72 training loss: 0.0012595160567963665 acc: 0.9996382054992764
# epoch 72 validation acc: 0.8798701
# epoch 72 time cost: 1.3395869731903076
# Train Epoch: 73 [0%]	Loss: 0.000214
# epoch 73 training loss: 0.002019323764464141 acc: 0.9992764109985528
# epoch 73 validation acc: 0.8863636
# epoch 73 time cost: 1.3599309921264648
# Train Epoch: 74 [0%]	Loss: 0.000431
# epoch 74 training loss: 0.0012982423054795204 acc: 0.9996382054992764
# epoch 74 validation acc: 0.8831169
# epoch 74 time cost: 1.3716530799865723
# Train Epoch: 75 [0%]	Loss: 0.000133
# epoch 75 training loss: 0.0007706842026726173 acc: 1.0
# epoch 75 validation acc: 0.8863636
# epoch 75 time cost: 1.3449947834014893
# Train Epoch: 76 [0%]	Loss: 0.000953
# epoch 76 training loss: 0.000558722160018409 acc: 1.0
# epoch 76 validation acc: 0.8863636
# epoch 76 time cost: 1.321789026260376
# Train Epoch: 77 [0%]	Loss: 0.000382
# epoch 77 training loss: 0.000839766295526219 acc: 1.0
# epoch 77 validation acc: 0.8961039
# epoch 77 time cost: 1.3199889659881592
# Train Epoch: 78 [0%]	Loss: 0.000514
# epoch 78 training loss: 0.0005173402804013511 acc: 1.0
# epoch 78 validation acc: 0.8896104
# epoch 78 time cost: 1.3409810066223145
# Train Epoch: 79 [0%]	Loss: 0.000153
# epoch 79 training loss: 0.0005627672799164429 acc: 1.0
# epoch 79 validation acc: 0.8831169
# epoch 79 time cost: 1.3202059268951416
# Train Epoch: 80 [0%]	Loss: 0.001426
# epoch 80 training loss: 0.0004954054443673654 acc: 1.0
# epoch 80 validation acc: 0.8896104
# epoch 80 time cost: 1.3285579681396484
# Train Epoch: 81 [0%]	Loss: 0.000183
# epoch 81 training loss: 0.00021940657659962943 acc: 1.0
# epoch 81 validation acc: 0.8863636
# epoch 81 time cost: 1.345344066619873
# Train Epoch: 82 [0%]	Loss: 0.000133
# epoch 82 training loss: 0.00020729230494577098 acc: 1.0
# epoch 82 validation acc: 0.8831169
# epoch 82 time cost: 1.3509409427642822
# Train Epoch: 83 [0%]	Loss: 0.000130
# epoch 83 training loss: 0.00017253454974376257 acc: 1.0
# epoch 83 validation acc: 0.8831169
# epoch 83 time cost: 1.3175511360168457
# Train Epoch: 84 [0%]	Loss: 0.000180
# epoch 84 training loss: 0.00017382553084065546 acc: 1.0
# epoch 84 validation acc: 0.8863636
# epoch 84 time cost: 1.3491020202636719
# Train Epoch: 85 [0%]	Loss: 0.000115
# epoch 85 training loss: 0.00016716629033908248 acc: 1.0
# epoch 85 validation acc: 0.8798701
# epoch 85 time cost: 1.3895790576934814
# Train Epoch: 86 [0%]	Loss: 0.000141
# epoch 86 training loss: 0.00016349894510560924 acc: 1.0
# epoch 86 validation acc: 0.8863636
# epoch 86 time cost: 1.3146491050720215
# Train Epoch: 87 [0%]	Loss: 0.000272
# epoch 87 training loss: 0.00014612631060696333 acc: 1.0
# epoch 87 validation acc: 0.8863636
# epoch 87 time cost: 1.3506927490234375
# Train Epoch: 88 [0%]	Loss: 0.000130
# epoch 88 training loss: 0.0001489971096320501 acc: 1.0
# epoch 88 validation acc: 0.8863636
# epoch 88 time cost: 1.317270040512085
# Train Epoch: 89 [0%]	Loss: 0.000243
# epoch 89 training loss: 0.00014362763613462448 acc: 1.0
# epoch 89 validation acc: 0.8831169
# epoch 89 time cost: 1.3295297622680664
# Train Epoch: 90 [0%]	Loss: 0.000114
# epoch 90 training loss: 0.00013575946600626182 acc: 1.0
# epoch 90 validation acc: 0.8831169
# epoch 90 time cost: 1.3403921127319336
# Train Epoch: 91 [0%]	Loss: 0.000099
# epoch 91 training loss: 0.00013750652843472463 acc: 1.0
# epoch 91 validation acc: 0.8863636
# epoch 91 time cost: 1.3162519931793213
# Train Epoch: 92 [0%]	Loss: 0.000091
# epoch 92 training loss: 0.00013519366720257412 acc: 1.0
# epoch 92 validation acc: 0.8863636
# epoch 92 time cost: 1.3775770664215088
# Train Epoch: 93 [0%]	Loss: 0.000385
# epoch 93 training loss: 0.00012645190360093363 acc: 1.0
# epoch 93 validation acc: 0.8863636
# epoch 93 time cost: 1.3821139335632324
# Train Epoch: 94 [0%]	Loss: 0.000112
# epoch 94 training loss: 0.00012446785876818467 acc: 1.0
# epoch 94 validation acc: 0.8863636
# epoch 94 time cost: 1.3174800872802734
# Train Epoch: 95 [0%]	Loss: 0.000109
# epoch 95 training loss: 0.00012081518781831784 acc: 1.0
# epoch 95 validation acc: 0.8863636
# epoch 95 time cost: 1.317845106124878
# Train Epoch: 96 [0%]	Loss: 0.000145
# epoch 96 training loss: 0.00012016420011853121 acc: 1.0
# epoch 96 validation acc: 0.8831169
# epoch 96 time cost: 1.346235752105713
# Train Epoch: 97 [0%]	Loss: 0.000076
# epoch 97 training loss: 0.00011974890466345559 acc: 1.0
# epoch 97 validation acc: 0.8863636
# epoch 97 time cost: 1.3231728076934814
# Train Epoch: 98 [0%]	Loss: 0.000090
# epoch 98 training loss: 0.00011093350159088996 acc: 1.0
# epoch 98 validation acc: 0.8831169
# epoch 98 time cost: 1.3216729164123535
# Train Epoch: 99 [0%]	Loss: 0.000084
# epoch 99 training loss: 0.00011331121707123451 acc: 1.0
# epoch 99 validation acc: 0.8863636
# epoch 99 time cost: 1.3448560237884521

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# np.int64(33)

# %%
checkpoint=torch.load('H4P2T2_CNN_best.pt', weights_only=False)
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.9102731
# Sensitivity [0.86931819 0.8831169  0.89041096 0.96721309 0.95321637]
# Precision [0.84530389 0.87179488 0.95588237 0.90769231 0.98192769]
# Confusion
#  [[153  16   2   4   1]
#  [ 15 136   2   1   0]
#  [  6   1 130   7   2]
#  [  4   0   0 118   0]
#  [  3   3   2   0 163]]

# %% [markdown]
# ### You will get zero score if the test accuracy < 85%

# %%
if acc < 0.85:
    print("zero point for this task")       
else:
    print("good job")
# Out:
# good job

# %% [markdown]
# ### submit this ipynb file and H4P2T2_CNN_best.pt if acc >= 0.85
